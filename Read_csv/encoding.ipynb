# %%
import pandas as pd
? pd.read_csv

# %% [markdown]
# encoding : str, optional
#     Encoding to use for UTF when reading/writing (ex. 'utf-8'). `List of Python
#     standard encodings
#     <https://docs.python.org/3/library/codecs.html#standard-encodings>`_ .

# %%
path = "C:\\Users\\nhant\\Documents\\GitHub\\DA-in-Python\\Untitled Folder\\"
df = pd.read_csv(path + "Data_201905 (Mau).csv", encoding = 'ISO-8859-1')

# %%
df
# Out:
#    Client No.  CHDRCOY   CHDRNUM CRTABLE  VALIDFLAG   EFFDATE  \
# 0    30000239        2  80030869    UL01          1  20190531
# 1    30000239        2  80030869    URA1          1  20190531
# 2    30000239        2  80030869    URC1          1  20190531
# 3    30000239        2  80030869    URC2          1  20190531
#
#             Full name    Birthday Reprting date       RCD  ... Policy Term  \
# 0  LÊ THI? NGO?C LIÊN  21/04/1976    31/05/2019  20180926  ...          57
# 1  LÊ THI? NGO?C LIÊN  21/04/1976    31/05/2019  20180926  ...          23
# 2  LÊ THI? NGO?C LIÊN  21/04/1976    31/05/2019  20180926  ...          23
# 3  LÊ THI? NGO?C LIÊN  21/04/1976    31/05/2019  20180926  ...          33
#
#    Attain Age  Loading_Plus  Loading_LI  Loading_CI  Loading_Dur       AV  \
# 0          43             0           0           0            0  4290000
# 1          43             0           0           0            0        0
# 2          43             0           0           0            0        0
# 3          43             0           0           0            0        0
#
#    Reserve    Protection AV    IAV
# 0         0             -      -
# 1         0             -      -
# 2         0             -      -
# 3         0             -      -
#
# [4 rows x 33 columns]
